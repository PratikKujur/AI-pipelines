# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as trasforms
import matplotlib.pyplot as plt

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
input_size=784
hidden_size=100
num_classes=10
epochs=2
batch_size=100
learning_rate=0.001

# %%
train_dataset=torchvision.datasets.MNIST(root='./data',train=True,transform=trasforms.ToTensor(),download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:54<00:00, 182kB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 70.7kB/s]
# 100%|██████████| 1.65M/1.65M [00:10<00:00, 151kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 2.28MB/s]

# %%
test_dataset=torchvision.datasets.MNIST(root='./data',train=True,transform=trasforms.ToTensor(),download=False)

# %%
train_loader=torch.utils.data.DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True)
test_loader=torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=True)

# %%
examples=iter(train_loader)
samples,labels=examples.next()

print(samples.shape,labels.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 examples=iter(train_loader)
# ----> 2 samples,labels=examples.next
#       4 print(samples.shape,labels.shape)
#
# AttributeError: '_SingleProcessDataLoaderIter' object has no attribute 'next'

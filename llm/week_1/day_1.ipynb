# %%
from langchain_groq import ChatGroq
import os
from groq import Groq

# %%
api_key=os.getenv('GROQ_API')
model="llama-3.1-8b-instant"
if not api_key:
    print("api key not imported correctly")

# %%
llm=ChatGroq(api_key=api_key,model=model)

# %%
client=Groq(api_key=api_key)

# %%
message="Differene between fine-tunning and transfer learning"

chat_completion=client.chat.completions.create(
    messages=[{
    "role":"system",
     "content":"You are a helpful assistant"
    },
    {
        "role":"user",
        "content":message
    }
],
model=model
)

# %%
response=chat_completion.choices[0].message.content
print(response)
# Out:
# Fine-tuning and transfer learning are two related but distinct concepts in the field of deep learning and artificial intelligence. While they are often used interchangeably, there are some subtle differences between them.
#
# **Transfer Learning:**
# Transfer learning is a technique where a pre-trained model, typically on a large dataset, is used as a starting point for a different task or problem. The pre-trained model has learned general features and representations that can be applied to a new task, rather than having to start from a completely random initialization. This is particularly useful when the new task has a small or imbalanced dataset.
#
# **Fine-tuning:**
# Fine-tuning is a process that builds on top of transfer learning. Once a pre-trained model has been chosen, the goal is to adapt it to the specific problem at hand, often with a smaller dataset. Fine-tuning involves adjusting the weights of the pre-trained model's layers, or even adding new layers on top, to customize the model to the specific task or dataset. Fine-tuning is often used to adjust the features learned in the pre-training process to better fit the new task.
#
# **Key differences:**
#
# 1. **Starting point:** Transfer learning starts with a pre-trained model, whereas fine-tuning starts with a fully pre-trained model.
# 2. **Number of layers:** In transfer learning, the entire model (or most layers) is used, whereas fine-tuning might require adjusting or adding only specific layers to adapt to the new task.
# 3. **Objective:** The primary objective of transfer learning is to use general features learned in a pre-trained model for a new task, whereas fine-tuning aims to tweak the pre-trained model to better fit a specific problem or dataset.
# 4. **Dataset size:** Transfer learning is typically used when the dataset for the new task is small, whereas fine-tuning is often applied when the dataset for the new task is moderate or large.
#
# To illustrate the difference, consider the following analogy:
#
# Transfer learning is like using a map (pre-trained model) that was created by a traveler (data scientist) who explored a large area (dataset). You're not the traveler, but you can use their map to navigate a smaller area (new task).
#
# Fine-tuning is like asking the traveler (data scientist) to adapt their map to include your specific route (customizing the pre-trained model to a new dataset).
#
# I hope this clarifies the difference between transfer learning and fine-tuning!
